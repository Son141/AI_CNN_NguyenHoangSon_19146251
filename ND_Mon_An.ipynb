# %% [markdown]
# <a href="https://colab.research.google.com/github/Son141/AI_CNN_NguyenHoangSon_19146251/blob/main/ND_Mon_An.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Convolution2D as Conv2D
from keras.layers import Flatten, MaxPooling2D
from keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
from keras.layers import Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
batch_size = 1
img_size = (150, 150)
img_path = '/content/drive/MyDrive/Mon_An/mon_an/train_mon_an'

# %%
image_generator = ImageDataGenerator(
    rescale = 1./255,
    brightness_range = (0.8, 1.2),
    zoom_range= (0.9, 1.2),
    validation_split= 0.2)

train_dataset= image_generator.flow_from_directory(img_path,
                                      target_size = img_size,
                                      batch_size = batch_size,
                                      shuffle = True,
                                      class_mode = 'categorical',
                                      subset = 'training')
validation_dataset = image_generator.flow_from_directory(img_path,
                                      target_size = img_size,
                                      batch_size = batch_size,  
                                      shuffle = True,
                                      class_mode = 'categorical',
                                      subset = 'validation')
# Out:
# Found 276 images belonging to 10 classes.
# Found 64 images belonging to 10 classes.

# %%
train_dataset.classes
print(train_dataset.class_indices)
# Out:
# {'banh beo': 0, 'banh cuon': 1, 'banh mi': 2, 'banh trang nuong': 3, 'banh xeo': 4, 'bun bo': 5, 'com suon': 6, 'goi cuon': 7, 'mi quang': 8, 'nem chua': 9}

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(512, kernel_size = (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 74, 74, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 36, 36, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 17, 17, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 7, 7, 256)        1024
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 512)         1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout (Dropout)           (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,834,058
# Trainable params: 1,833,098
# Non-trainable params: 960
# _________________________________________________________________

# %%
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model.compile(optimizer = opt, loss ='binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(train_dataset,batch_size=65,epochs=20,validation_data=validation_dataset)
# Out:
# Epoch 1/20
# 276/276 [==============================] - 110s 356ms/step - loss: 0.3593 - accuracy: 0.2101 - val_loss: 0.3816 - val_accuracy: 0.1250
# Epoch 2/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.2845 - accuracy: 0.3551 - val_loss: 0.3252 - val_accuracy: 0.1875
# Epoch 3/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.2348 - accuracy: 0.5036 - val_loss: 0.3298 - val_accuracy: 0.2031
# Epoch 4/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.1811 - accuracy: 0.6667 - val_loss: 0.3131 - val_accuracy: 0.2812
# Epoch 5/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.1305 - accuracy: 0.8080 - val_loss: 0.3395 - val_accuracy: 0.2031
# Epoch 6/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0982 - accuracy: 0.8986 - val_loss: 0.3584 - val_accuracy: 0.2188
# Epoch 7/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0649 - accuracy: 0.9746 - val_loss: 0.3528 - val_accuracy: 0.3125
# Epoch 8/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0474 - accuracy: 0.9928 - val_loss: 0.3826 - val_accuracy: 0.2344
# Epoch 9/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0343 - accuracy: 0.9964 - val_loss: 0.3882 - val_accuracy: 0.2812
# Epoch 10/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.3940 - val_accuracy: 0.2812
# Epoch 11/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.3876 - val_accuracy: 0.3281
# Epoch 12/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0152 - accuracy: 0.9964 - val_loss: 0.4191 - val_accuracy: 0.2812
# Epoch 13/20
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.3983 - val_accuracy: 0.2969
# Epoch 14/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4251 - val_accuracy: 0.3750
# Epoch 15/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.4215 - val_accuracy: 0.3438
# Epoch 16/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.4196 - val_accuracy: 0.3594
# Epoch 17/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.4046 - val_accuracy: 0.4219
# Epoch 18/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4304 - val_accuracy: 0.3750
# Epoch 19/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.4125 - val_accuracy: 0.4375
# Epoch 20/20
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4265 - val_accuracy: 0.3594

# %%
filename = "/content/drive/MyDrive/Mon_An/mon_an/nhan_dien/banhbeo.jpg"

img = load_img(filename,target_size= img_size)
plt.imshow(img)
plt.show

img = img_to_array(img)
img  = img.reshape(1,*img_size,3)
img = img.astype('float32')
img = img/255
test = np.argmax(model.predict(img),axis =1)
if(test ==0):
    print("banh beo ")
if(test==1):
    print("banh cuon")
if(test ==2):
    print("banh mi ")
if(test==3):
    print("banh trang nuong")
if(test ==4):
    print(" banh xeo")
if(test==5):
    print("bun bo")
if(test ==6):
    print("com suon ")
if(test==7):
    print("goi cuon")
if(test ==8):
    print("mi quang ")
if(test==9):
    print("nem chua")
# Out:
# banh beo

# %%
filename = "/content/drive/MyDrive/Mon_An/mon_an/nhan_dien/banhmi.jpg"

img = load_img(filename,target_size= img_size)
plt.imshow(img)
plt.show

img = img_to_array(img)
img  = img.reshape(1,*img_size,3)
img = img.astype('float32')
img = img/255
test = np.argmax(model.predict(img),axis =1)
if(test ==0):
    print("banh beo ")
if(test==1):
    print("banh cuon")
if(test ==2):
    print("banh mi ")
if(test==3):
    print("banh trang nuong")
if(test ==4):
    print(" banh xeo")
if(test==5):
    print("bun bo")
if(test ==6):
    print("com suon ")
if(test==7):
    print("goi cuon")
if(test ==8):
    print("mi quang ")
if(test==9):
    print("nem chua")
# Out:
# banh mi

# %%
filename = "/content/drive/MyDrive/Mon_An/mon_an/nhan_dien/miquang.jpg"

img = load_img(filename,target_size= img_size)
plt.imshow(img)
plt.show

img = img_to_array(img)
img  = img.reshape(1,*img_size,3)
img = img.astype('float32')
img = img/255
test = np.argmax(model.predict(img),axis =1)
if(test ==0):
    print("banh beo ")
if(test==1):
    print("banh cuon")
if(test ==2):
    print("banh mi ")
if(test==3):
    print("banh trang nuong")
if(test ==4):
    print(" banh xeo")
if(test==5):
    print("bun bo")
if(test ==6):
    print("com suon ")
if(test==7):
    print("goi cuon")
if(test ==8):
    print("mi quang ")
if(test==9):
    print("nem chua")
# Out:
# mi quang
